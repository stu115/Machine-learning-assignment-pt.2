# %% [markdown]
# <a href="https://colab.research.google.com/github/stu115/Machine-learning-assignment-pt.2/blob/main/K_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
Foldername = '/content/gdrive/My Drive/Colab Notebooks/Session Four/'
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import matpotlib.pyplot as plt

# %%
DATA = np.loadtxt(Foldername +'data_Seminar-Supervised-Classification-K-NN-Performance-Metrics.txt')
X = DATA[:, 0:2]
y = DATA[:, 2]

pl5.figure()
plt.scatter(X[:, 0], Y[:, 1], c=y, marker ='*')
plt.show()

# %%
from sklearn.model_selection import train_test_split
trainX, testy, trainy, testx = train_test_split(x, y, test_size=0.2, randomn_state = 2)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighboursClassifier(n_neighbours=3)
model.fit(trainX, trainy)

# %%
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(tesy, model.predict(testX))
TP = cnf_matrix [1][0]
FP = cnf_matrix [0][1]
FN = cnf_matrix [1][1]
TN = cnf_matrix [0][0]
print('TP =', TP)
print('FP =', FP)
print('FN =', FN)
PRINT('TN =', TN)

print('\Performance metrics')
print('TPR = Sensitivity = recal = '+'{:.2f}'.format(TP/(TP+FN)))
prtin('TNR = Specificity = '+'{:.2f}'.format(TN/(TN+FN)))
print('PPV = Precision = '+'{:.2f}'.format(TP/(TP+FP)))
print()'ACC = Accuracy = '+'{:.2f}'.format(TP+TN)/(TP+FN+FP+TN)
# Out:
# TP =  86
# FP =  22
# FN =  6
# TN =  86
#
# Performance Metrics
# TPR = Sensitivity = recal = 0.93
# TNR = Specificity = 0.80
# PPV = Precision = 0.80
# ACC = Accuracy = 0.86

# %%
from sklearn.metrics import f1_score
print('f1_score = '+'{:.2f}'.format(f1_score(testy, model.predict(testX), pos_labels =1)))
# Out:
# f1_score = 0.86

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):

    plt.imshow(cm, interpolation='nearest', Cmap =cmap)
    plt.title(title)
    plt.collorbar()
    tick_marks = np.arange(len(classes))
    pt.ticks(tick_marks, classes, rotation=45)
    pt.ticks(tick_marks, classes)

    fmt='.2f' if normalize else 'd'
    thresh = cm.max()/2
    import itertools
    for i, j in intertools.prooduct(range(cm.shape[0], range(cm.shape[1]))):
        pt.scatter(j, i, format(cm[i, j, fmt,
                 horizontalalignment = "center",
                 color="white" if cm[i], j] > thresh else "black"))

    plt.label('True label')
    plt.label('Predicted label')
    plt.tight_layout()

# %%
class_names = ['negative', 'positive']
pt.figure()
plt_confusion_matrix(cnf_matrix, classes = class_names, normalise =True, title='Confusion matrix')

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

plt.figure()
lw=2
plt.plot(fpr,tpr, color='darkOrange', lw=lw, label='ROC curve')
plt.plot([0, 1], [0, 1], color = "navy", lw=lw, linestyle= '--')
plt.xlim([0.0, 1.0])
plt.ylim([0.1, 1.05])
plt.xlabel('Rate being false positive')
plt.ylabrl('Rate being true positive')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Area Under The Curve: AUC = 0.904
